# %%
import os
from dotenv import load_dotenv
import pandas as pd

pd.set_option('display.max_columns', None)
load_dotenv()

endpoint   = os.getenv("MINIO_ENDPOINT")
bucket     = os.getenv("MINIO_BUCKET")
parquet    = os.getenv("MINIO_PARQUET_PATH")
access_key = os.getenv("MINIO_ACCESS_KEY")
secret_key = os.getenv("MINIO_SECRET_KEY")
parquetpath = os.getenv("MINIO_PARQUET_PATH")

storage_opts = {
    "key": access_key,
    "secret": secret_key,
    "client_kwargs": {"endpoint_url": endpoint},
}

path = f"s3://{bucket}/{parquetpath}/add_posdoc.parquet"
df = pd.read_parquet(path, storage_options=storage_opts)

# %%
df.columns
# Out:
# Index(['ID_POS_DOC', 'AN_BASE', 'ID_ADD_FOTO_PROGRAMA', 'CD_PROGRAMA',
#        'NM_PROGRAMA', 'ID_ADD_FOTO_PROGRAMA_IES', 'SG_IES', 'NM_IES',
#        'SG_UF_PROGRAMA_IES', 'NM_UF', 'ID_AREA_AVALIACAO', 'NM_AREA_AVALIACAO',
#        'NM_PESSOA_POS_DOC', 'TP_SEXO', 'DT_NASCIMENTO', 'DS_EMAIL',
#        'NM_PAIS_NACIONALIDADE', 'ID_TP_IDENTIFICADOR', 'NM_TP_IDENTIFICADOR',
#        'NR_DOCUMENTO', 'ID_PAIS_IDENTIFICADOR', 'NM_PAIS_IDENTIFICADOR',
#        'DT_INICIO_TITULACAO', 'DT_FIM_TITULACAO',
#        'ID_AREA_CONHECIMENTO_FORMACAO', 'CD_AREA_CONHECIMENTO_FORMACAO',
#        'NM_AREA_CONHECIMENTO_FORMACAO', 'ID_IES_TITULACAO', 'SG_IES_TITULACAO',
#        'NM_IES_TITULACAO', 'ID_PAIS_IES_TITULACAO', 'NM_PAIS_IES_TITULACAO',
#        'ID_GRAU_ACADEMICO', 'NM_GRAU_ACADEMICO', 'DH_INICIO_POS_DOC',
#        'DH_FIM_POS_DOC', 'NR_ORCID_POS_DOC', 'DT_CARGA'],
#       dtype='object')

# %%
df
# Out:
#         ID_POS_DOC  AN_BASE  ID_ADD_FOTO_PROGRAMA    CD_PROGRAMA  \
# 0               21     2019                 76902  30001013040P7
# 1               22     2019                 76902  30001013040P7
# 2              101     2019                 77044  25016016002P7
# 3              273     2019                 77249  51001012029P2
# 4              274     2019                 77249  51001012029P2
# ...            ...      ...                   ...            ...
# 115010      245955     2024                192364  42001013105P5
# 115011      245956     2024                192364  42001013105P5
# 115012      245957     2024                192364  42001013105P5
# 115013      245958     2024                192364  42001013105P5
# 115014      245959     2024                192364  42001013105P5
#
#                                             NM_PROGRAMA  \
# 0                               BIODIVERSIDADE TROPICAL
# 1                               BIODIVERSIDADE TROPICAL
# 2                  Ciências Sociais para o Ensino Médio
# 3                                       Biologia Animal
# 4                                       Biologia Animal
# ...                                                 ...
# 115010  Ciências Biológicas: Farmacologia e Terapêutica
# 115011  Ciências Biológicas: Farmacologia e Terapêutica
# 115012  Ciências Biológicas: Farmacologia e Terapêutica
# 115013  Ciências Biológicas: Farmacologia e Terapêutica
# 115014  Ciências Biológicas: Farmacologia e Terapêutica
#
#         ID_ADD_FOTO_PROGRAMA_IES SG_IES  \
# 0                         141636   UFES
# 1                         141636   UFES
# 2                         141778    FJN
# 3                         141963   UFMS
# 4                         141963   UFMS
# ...                          ...    ...
# 115010                    256001  UFRGS
# 115011                    256001  UFRGS
# 115012                    256001  UFRGS
# 115013                    256001  UFRGS
# 115014                    256001  UFRGS
#
#                                                    NM_IES SG_UF_PROGRAMA_IES  \
# 0                  UNIVERSIDADE FEDERAL DO ESPÍRITO SANTO                 ES
# 1                  UNIVERSIDADE FEDERAL DO ESPÍRITO SANTO                 ES
# 2                                 FUNDACAO JOAQUIM NABUCO                 PE
# 3       FUNDAÇÃO UNIVERSIDADE FEDERAL DE MATO GROSSO D...                 MS
# 4       FUNDAÇÃO UNIVERSIDADE FEDERAL DE MATO GROSSO D...                 MS
# ...                                                   ...                ...
# 115010          UNIVERSIDADE FEDERAL DO RIO GRANDE DO SUL                 RS
# 115011          UNIVERSIDADE FEDERAL DO RIO GRANDE DO SUL                 RS
# 115012          UNIVERSIDADE FEDERAL DO RIO GRANDE DO SUL                 RS
# 115013          UNIVERSIDADE FEDERAL DO RIO GRANDE DO SUL                 RS
# 115014          UNIVERSIDADE FEDERAL DO RIO GRANDE DO SUL                 RS
#
#                      NM_UF  ID_AREA_AVALIACAO  \
# 0           Espírito Santo                  7
# 1           Espírito Santo                  7
# 2               Pernambuco                 34
# 3       Mato Grosso do Sul                  7
# 4       Mato Grosso do Sul                  7
# ...                    ...                ...
# 115010   Rio Grande do Sul                  8
# 115011   Rio Grande do Sul                  8
# 115012   Rio Grande do Sul                  8
# 115013   Rio Grande do Sul                  8
# 115014   Rio Grande do Sul                  8
#
#                                         NM_AREA_AVALIACAO  \
# 0                                          BIODIVERSIDADE
# 1                                          BIODIVERSIDADE
# 2       SOCIOLOGIA                                    ...
# 3                                          BIODIVERSIDADE
# 4                                          BIODIVERSIDADE
# ...                                                   ...
# 115010  CIÊNCIAS BIOLÓGICAS II                        ...
# 115011  CIÊNCIAS BIOLÓGICAS II                        ...
# 115012  CIÊNCIAS BIOLÓGICAS II                        ...
# 115013  CIÊNCIAS BIOLÓGICAS II                        ...
# 115014  CIÊNCIAS BIOLÓGICAS II                        ...
#
#                        NM_PESSOA_POS_DOC TP_SEXO DT_NASCIMENTO  \
# 0         MARIA CECILIA MARTINS KIERULFF      F     1962-02-14
# 1             LEONARDO FRANCISCO MACHADO      M     1974-08-14
# 2                          SIMONE MEUCCI      F     1970-10-08
# 3                            NINA ATTIAS      F     1985-01-16
# 4                        RICARDO KOROIVA      M     1986-12-12
# ...                                  ...     ...           ...
# 115010        PABULO HENRIQUE RAMPELOTTO      M     1987-02-04
# 115011         MARCO ANTONIO DE BASTIANI      M     1987-07-14
# 115012  WYLLIANS JOSE VENDRAMINI BORELLI      M     1991-02-23
# 115013                 DIRSON JOAO STEIN      M     1974-02-12
# 115014                    BRUNA BELLAVER      F     1990-03-19
#
#                           DS_EMAIL NM_PAIS_NACIONALIDADE  ID_TP_IDENTIFICADOR  \
# 0            KIERULFF@TERRA.COM.BR                Brasil                    1
# 1          DUSKY.GROUPER@GMAIL.COM                Brasil                    1
# 2       simonemeucci2010@gmail.com                Brasil                    1
# 3            NINA.ATTIAS@GMAIL.COM                Brasil                    1
# 4        ricardo.koroiva@gmail.com                Brasil                    1
# ...                            ...                   ...                  ...
# 115010         pabulobio@gmail.com                Brasil                    1
# 115011           tyrev@hotmail.com                Brasil                    1
# 115012       wyllians.vb@gmail.com                Brasil                    1
# 115013          dirstein@gmail.com                Brasil                    1
# 115014   brunabellaver90@gmail.com                Brasil                    1
#
#        NM_TP_IDENTIFICADOR NR_DOCUMENTO  ID_PAIS_IDENTIFICADOR  \
# 0                      CPF  69254834653                     31
# 1                      CPF  88657558904                     31
# 2                      CPF  77371801920                     31
# 3                      CPF  10695196774                     31
# 4                      CPF  34871813800                     31
# ...                    ...          ...                    ...
# 115010                 CPF  01176850032                     31
# 115011                 CPF  00514973013                     31
# 115012                 CPF  02006590065                     31
# 115013                 CPF  76055809087                     31
# 115014                 CPF  01892152088                     31
#
#        NM_PAIS_IDENTIFICADOR DT_INICIO_TITULACAO DT_FIM_TITULACAO  \
# 0                     Brasil                 NaT       2000-12-31
# 1                     Brasil                 NaT       2010-12-31
# 2                     Brasil                 NaT       2006-12-31
# 3                     Brasil          2013-03-06       2017-12-31
# 4                     Brasil          2013-11-11       2017-12-31
# ...                      ...                 ...              ...
# 115010                Brasil          2015-01-08       2019-12-31
# 115011                Brasil          2015-03-13       2019-12-31
# 115012                Brasil          2015-08-03       2019-12-31
# 115013                Brasil                 NaT       2018-12-31
# 115014                Brasil          2015-03-12       2019-12-31
#
#         ID_AREA_CONHECIMENTO_FORMACAO CD_AREA_CONHECIMENTO_FORMACAO  \
# 0                                  32                      20100000
# 1                                  16                      20400004
# 2                                 334                      70207003
# 3                                  17                      20500009
# 4                                  17                      20500009
# ...                               ...                           ...
# 115010                             32                      20100000
# 115011                             20                      20800002
# 115012                            267                      40101002
# 115013                             19                      20700008
# 115014                             20                      20800002
#
#          NM_AREA_CONHECIMENTO_FORMACAO  ID_IES_TITULACAO SG_IES_TITULACAO  \
# 0                       BIOLOGIA GERAL            801739             None
# 1                             ZOOLOGIA            801729             UTAD
# 2       OUTRAS SOCIOLOGIAS ESPECÍFICAS              4296          UNICAMP
# 3                             ECOLOGIA              5136             UFMS
# 4                             ECOLOGIA              5136             UFMS
# ...                                ...               ...              ...
# 115010                  BIOLOGIA GERAL              4358            UFRGS
# 115011                      BIOQUÍMICA              4358            UFRGS
# 115012                  CLÍNICA MÉDICA              3046            PUCRS
# 115013                      FISIOLOGIA              4358            UFRGS
# 115014                      BIOQUÍMICA              4358            UFRGS
#
#                                          NM_IES_TITULACAO  \
# 0                                 UNIVERSITY OF CAMBRIDGE
# 1             UNIVERSIDADE DE TRÁS-OS-MONTES E ALTO DOURO
# 2                       UNIVERSIDADE ESTADUAL DE CAMPINAS
# 3       FUNDAÇÃO UNIVERSIDADE FEDERAL DE MATO GROSSO D...
# 4       FUNDAÇÃO UNIVERSIDADE FEDERAL DE MATO GROSSO D...
# ...                                                   ...
# 115010          UNIVERSIDADE FEDERAL DO RIO GRANDE DO SUL
# 115011          UNIVERSIDADE FEDERAL DO RIO GRANDE DO SUL
# 115012  PONTIFÍCIA UNIVERSIDADE CATÓLICA DO RIO GRANDE...
# 115013          UNIVERSIDADE FEDERAL DO RIO GRANDE DO SUL
# 115014          UNIVERSIDADE FEDERAL DO RIO GRANDE DO SUL
#
#         ID_PAIS_IES_TITULACAO NM_PAIS_IES_TITULACAO  ID_GRAU_ACADEMICO  \
# 0                         188           Reino Unido               28.0
# 1                         184              Portugal               28.0
# 2                          31                Brasil               28.0
# 3                          31                Brasil               28.0
# 4                          31                Brasil               28.0
# ...                       ...                   ...                ...
# 115010                     31                Brasil               28.0
# 115011                     31                Brasil               28.0
# 115012                     31                Brasil               28.0
# 115013                     31                Brasil               28.0
# 115014                     31                Brasil               28.0
#
#        NM_GRAU_ACADEMICO DH_INICIO_POS_DOC DH_FIM_POS_DOC  NR_ORCID_POS_DOC  \
# 0              Doutorado        2014-01-01            NaT              None
# 1              Doutorado        2013-01-01            NaT              None
# 2              Doutorado        2016-09-14            NaT              None
# 3              Doutorado        2018-06-01            NaT              None
# 4              Doutorado        2018-06-01     2019-02-28              None
# ...                  ...               ...            ...               ...
# 115010         Doutorado        2022-11-18     2024-02-05              None
# 115011         Doutorado        2022-03-01            NaT  0000000339245278
# 115012         Doutorado        2021-08-01     2024-06-10  0000000192820601
# 115013         Doutorado        2019-03-20            NaT  0000000306960195
# 115014         Doutorado        2019-03-01            NaT  0000000222123373
#
#                   DT_CARGA
# 0      2025-03-12 10:17:51
# 1      2025-03-12 10:17:59
# 2      2025-03-12 10:17:51
# 3      2025-03-12 10:17:54
# 4      2025-03-12 10:17:53
# ...                    ...
# 115010 2025-03-12 10:17:54
# 115011 2025-03-12 10:17:55
# 115012 2025-03-12 10:17:50
# 115013 2025-03-12 10:17:52
# 115014 2025-03-12 10:17:57
#
# [115015 rows x 38 columns]

# %%
# Verificar informações sobre o DataFrame
print(f"Número de linhas: {len(df)}")
print(f"Número de colunas: {len(df.columns)}")
print(f"Forma (shape): {df.shape}")
print(f"DataFrame vazio: {df.empty}")
# Out:
# Número de linhas: 115015
# Número de colunas: 38
# Forma (shape): (115015, 38)
# DataFrame vazio: False
